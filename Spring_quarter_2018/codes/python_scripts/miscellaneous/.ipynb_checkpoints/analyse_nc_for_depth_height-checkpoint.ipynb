# %%
# %matplotlib inline
import numpy as np
import netCDF4 as nc
import sys
import os.path
import pylab as py
import matplotlib.cm as cm
import errno
def reverse_colourmap(cmap, name = 'my_cmap_r'):
    reverse = []
    k = []

    for key in cmap._segmentdata:
        k.append(key)
        channel = cmap._segmentdata[key]
        data = []

        for t in channel:
            data.append((1-t[0],t[2],t[1]))
        reverse.append(sorted(data))

    LinearL = dict(zip(k,reverse))
    my_cmap_r = mpl.colors.LinearSegmentedColormap(name, LinearL)
    return my_cmap_r

py.rc('text', usetex=True)
py.rc('font', family='serif', serif='Palatino',weight='bold')

#filename="/project2/tas1/pragallva/Fall_quarter_2017/exp_data/land/land_realqflux6.nc"
filename="/project2/tas1/pragallva/model/gfdl_data/zonal_actualzeroqflux/run002/atmos_4xdaily.nc"
print filename, 'ok'
data=nc.Dataset(filename,'r')
# print data.variables[dirc[1]]
print data.variables.keys()


def make_sure_path_exists(path):
    try:
        os.makedirs(path)
    except OSError as exception:
        if exception.errno != errno.EEXIST:
            raise
# Out:
# /project2/tas1/pragallva/model/gfdl_data/zonal_actualzeroqflux/run002/atmos_4xdaily.nc ok
# [u'lon', u'lonb', u'lat', u'latb', u'time', u'nv', u'pfull', u'phalf', u'scalar_axis', u'ps', u'pres_full', u'pres_half', u'bk', u'pk', u'ucomp', u'vcomp', u'temp', u'sphum', u'omega', u'zsurf', u'height', u'height_half', u'EKE', u'vor', u'div', u'flux_sw', u'flux_lw', u'rrtm_albedo', u'olr', u'coszen', u'toa_sw', u'flux_oceanq', u't_surf', u'flux_lhe', u'flux_t', u'ml_heat_cap', u'average_T1', u'average_T2', u'average_DT', u'time_bounds']

# %%
heat_cap = data.variables['ml_heat_cap'][:]
zsurf    = data.variables['zsurf'][:]

# %%
lat=data.variables['lat'][:]
lon=data.variables['lon'][:]

# %%
py.contourf(lon,lat, heat_cap)
py.contour(lon,lat, zsurf)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-a8e9c21ac9f0> in <module>()
#       1 py.contourf(lon,lat, heat_cap)
# ----> 2 py.contour(lon,lat, zsurf)
#
# /home/pragallva/Project1/lib/python2.7/site-packages/matplotlib/pyplot.pyc in contour(*args, **kwargs)
#    2852                       mplDeprecation)
#    2853     try:
# -> 2854         ret = ax.contour(*args, **kwargs)
#    2855     finally:
#    2856         ax._hold = washold
#
# /home/pragallva/Project1/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# ...

# %%
fig=py.figure(figsize=(15, 9))
py.plot(lat,-heat_cap.mean(axis=1)/4128868.52628,'b-',linewidth=3.5)
py.plot(lat,zsurf.mean(axis=1)/10**2,'m-',linewidth=3.5)
py.axhline(0,color='k')
py.tick_params(labelsize=40,size=5,width=2)
X=np.arange(-90, 91, 30)
py.xticks(X)
py.xlim(-90,90)
py.xlabel('latitude',fontsize=35)
py.tight_layout()
fig_dest="/project2/tas1/pragallva/Fall_quarter_2017/figures/bnd_profile/"
make_sure_path_exists(fig_dest)
# py.savefig(fig_dest+'my_land_profile.pdf')
py.show()

# %%
fileland="/project2/tas1/pragallva/Fall_quarter_2017/land_files/zonal_land.nc"
print fileland, 'ok'
data=nc.Dataset(fileland,'r')
# print data.variables[dirc[1]]
print data.variables.keys()
# Out:
# /project2/tas1/pragallva/Fall_quarter_2017/land_files/zonal_land.nc ok
# [u'lat', u'lon', u'zsurf', u'land_mask']

# %%
land_mask=data.variables['land_mask'][:]
py.contourf(lon,lat,land_mask); py.colorbar()

# %%
land_mean=land_mask.mean(axis=1)
depth=np.copy(land_mask.mean(axis=1))

# %%
zeros=(land_mean==0)
ones =(land_mean==1)
depth[zeros]=20
depth[ones]=2

# %%
py.plot(lat,-depth,'k.')
py.plot(lat,zsurf.mean(axis=1)/10**2,'r-')
py.axhline(0)

# %%
fig=py.figure(figsize=(15, 9))
py.plot(lat,-depth,'b-',linewidth=3.5)
py.plot(lat,zsurf.mean(axis=1)/10**2,'m-',linewidth=3.5)
py.axhline(0,color='k')
py.tick_params(labelsize=40,size=5,width=2)
X=np.arange(-90, 91, 30)
py.xticks(X)
py.xlim(-90,90)
py.xlabel('latitude',fontsize=35)
py.tight_layout()
fig_dest="/project2/tas1/pragallva/Fall_quarter_2017/figures/bnd_profile/"
make_sure_path_exists(fig_dest)
py.savefig(fig_dest+'zonal_land_profile.pdf')
py.show()

# %%
fileland="/project2/tas1/pragallva/Fall_quarter_2017/land_files/Ruth_full1.nc"
print fileland, 'ok'
data=nc.Dataset(fileland,'r')
# print data.variables[dirc[1]]
print data.variables.keys()
# Out:
# /project2/tas1/pragallva/Fall_quarter_2017/land_files/Ruth_full1.nc ok
# [u'lat', u'lon', u'zsurf', u'land_mask']

# %%
land_mask=data.variables['land_mask'][:]
zsurf=data.variables['zsurf'][:]

# %%
fig=py.figure(figsize=(15, 9))
py.contourf(lon,lat,land_mask)
py.contour(lon,lat,zsurf)
X=np.arange(0, 360, 60)
py.xticks(X)
Y=np.arange(-90, 91, 30)
py.yticks(Y)
py.ylim(-90,90)
py.tight_layout()
fig_dest="/project2/tas1/pragallva/Fall_quarter_2017/figures/bnd_profile/"
make_sure_path_exists(fig_dest)
py.tick_params(labelsize=40,size=5,width=2)
py.tight_layout()
py.savefig(fig_dest+'real_land_profile.pdf')
py.show()
